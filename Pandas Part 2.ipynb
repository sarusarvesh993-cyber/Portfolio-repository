# %%
import pandas as pd
import matplotlib.pyplot as plt
world = pd.read_csv('2018-2019 Happiness.csv')
airbnd = pd.read_csv('airbnb.csv')
salaries = pd.read_csv('salaries.csv')
websales= pd.read_csv('web_sales.csv')
eth = pd.read_csv('Ethereum Historical Data.csv', index_col='Date')

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1502 entries, 0 to 1501
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      1502 non-null   object
#  1   Coin      1502 non-null   object
#  2   Price     1502 non-null   float64
#  3   Open      1502 non-null   float64
#  4   High      1502 non-null   float64
#  5   Low       1502 non-null   float64
#  6   Vol.      1502 non-null   object
#  7   Change %  1502 non-null   object
# dtypes: float64(4), object(4)
# memory usage: 94.0+ KB

# %%
eth.index
# Out:
# RangeIndex(start=0, stop=1502, step=1)

# %%
eth.set_index('Date', inplace=True)

# %%
eth.reset_index( inplace=True)

# %%
eth
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_index()
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 0     10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 1      9/02/2024  ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 2      8/02/2024  ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 3      7/02/2024  ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 4      6/02/2024  ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 1497   5/01/2020  ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 1498   4/01/2020  ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 1499   3/01/2020  ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 1500   2/01/2020  ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1501   1/01/2020  ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 8 columns]

# %%
eth.sort_values(by = 'Price')
# Out:
#             Date Coin    Price     Open     High      Low     Vol. Change %
# 1430  12/03/2020  ETH   107.90   194.57   195.40   102.83   53.51M  -44.55%
# 1426  16/03/2020  ETH   111.02   124.35   124.38   102.44   40.25M  -10.72%
# 1425  17/03/2020  ETH   116.06   111.06   120.60   109.67   27.09M    4.54%
# 1424  18/03/2020  ETH   117.77   115.95   117.91   110.16   25.80M    1.47%
# 1420  22/03/2020  ETH   122.41   132.59   136.86   121.37   25.25M   -7.67%
# ...          ...  ...      ...      ...      ...      ...      ...      ...
# 819   13/11/2021  ETH  4644.61  4665.76  4705.02  4585.37  290.27K   -0.49%
# 820   12/11/2021  ETH  4667.31  4720.50  4807.16  4511.96  634.59K   -1.13%
# 821   11/11/2021  ETH  4720.87  4633.98  4778.17  4578.66  418.61K    1.87%
# 823    9/11/2021  ETH  4731.83  4808.34  4836.69  4715.43  437.41K   -1.59%
# 824    8/11/2021  ETH  4808.38  4612.05  4822.97  4612.05  673.21K    4.26%
#
# [1502 rows x 8 columns]

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 0          2023               EX              FT
# 1          2023               EX              FT
# 2          2023               MI              FT
# 3          2023               MI              FT
# 4          2023               SE              FT
# ...         ...              ...             ...
# 8800       2020               SE              FT
# 8801       2021               MI              FT
# 8802       2020               EN              FT
# 8803       2020               EN              CT
# 8804       2021               SE              FT
#
#                            job_title   salary salary_currency  salary_in_usd  \
# 0              Data Science Director   212000             USD         212000
# 1              Data Science Director   190000             USD         190000
# 2     Business Intelligence Engineer    35000             GBP          43064
# ...

# %%
salaries.sort_values(by = 'salary_in_usd', ascending=False)
# Out:
#       work_year experience_level employment_type  \
# 44         2023               EN              FL
# 8587       2020               MI              FT
# 7099       2022               MI              FT
# 5099       2023               MI              FT
# 8797       2021               MI              FT
# ...         ...              ...             ...
# 3332       2023               MI              FT
# 8207       2022               EN              FT
# 3071       2022               MI              FT
# 7910       2021               EN              FT
# 5282       2020               EX              FT
#
#                                job_title  salary salary_currency  \
# 44      Business Intelligence Consultant  500000             GBP
# 8587                  Research Scientist  450000             USD
# 7099                        Data Analyst  350000             GBP
# 5099                  Analytics Engineer  350000             GBP
# ...

# %%
salaries.sort_values(by = ['job_title','salary_in_usd'], ascending=[True, False], inplace=True)

# %%
salaries
# Out:
#       work_year experience_level employment_type  \
# 2543       2023               SE              FT
# 3357       2023               SE              FT
# 3697       2023               SE              FT
# 3895       2023               SE              FT
# 431        2023               SE              FT
# ...         ...              ...             ...
# 1672       2020               EN              CT
# 5282       2020               EX              FT
# 3505       2020               SE              FT
# 8690       2021               SE              CT
# 3504       2021               SE              FT
#
#                             job_title  salary salary_currency  salary_in_usd  \
# 2543                     AI Architect  330000             USD         330000
# 3357                     AI Architect  330000             USD         330000
# 3697                     AI Architect  330000             USD         330000
# ...

# %%
eth.loc[['25/12/2021','25/12/2022','25/12/2023'], ['Price','High']]
# Out:
#               Price     High
# Date
# 25/12/2021  4093.14  4136.03
# 25/12/2022  1218.69  1223.82
# 25/12/2023  2271.38  2303.28

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
airbnd.iloc[50]
# Out:
# Host Id                                                     5926
# Host Since                                             2/01/2009
# Name                          Nice  Apt Near Columbia University
# Neighbourhood                                          Manhattan
# Property Type                                    Bed & Breakfast
# Review Scores Rating (bin)                                  85.0
# Room Type                                           Private room
# Zipcode                                                  10031.0
# Beds                                                         1.0
# Number of Records                                              1
# Number Of Reviews                                             68
# Price                                                         55
# Review Scores Rating                                        86.0
# Name: 50, dtype: object

# %%
salaries['salary_in_usd'].value_counts()
# Out:
# salary_in_usd
# 150000    188
# 130000    179
# 160000    174
# 100000    157
# 120000    154
#          ...
# 106720      1
# 155810      1
# 45391       1
# 19609       1
# 91237       1
# Name: count, Length: 1768, dtype: int64

# %%
salaries['salary_in_usd'].value_counts().loc[150000]
# Out:
# np.int64(188)

# %%
world
# Out:
#      Overall rank  Year         Country or region  Score  GDP per capita  \
# 0               1  2019                   Finland  7.769           1.340
# 1               2  2019                   Denmark  7.600           1.383
# 2               3  2019                    Norway  7.554           1.488
# 3               4  2019                   Iceland  7.494           1.380
# 4               5  2019               Netherlands  7.488           1.396
# ..            ...   ...                       ...    ...             ...
# 307           152  2018                     Yemen  3.355           0.442
# 308           153  2018                  Tanzania  3.303           0.455
# 309           154  2018               South Sudan  3.254           0.337
# 310           155  2018  Central African Republic  3.083           0.024
# 311           156  2018                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
world.sort_index()
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Afghanistan                 154  2019  3.203           0.350           0.517
# Afghanistan                 145  2018  3.632           0.332           0.537
# Albania                     112  2018  4.586           0.916           0.817
# Albania                     107  2019  4.719           0.947           0.848
# Algeria                      84  2018  5.295           0.979           1.154
# ...                         ...   ...    ...             ...             ...
# Yemen                       152  2018  3.355           0.442           1.073
# Zambia                      138  2019  4.107           0.578           1.058
# Zambia                      125  2018  4.377           0.562           1.047
# Zimbabwe                    146  2019  3.663           0.366           1.114
# Zimbabwe                    144  2018  3.692           0.357           1.094
#
# ...

# %%
world_2019 = world[world['Year'] == 2019]
world_2019.loc['Canada':'Ireland']
# Out:
#                    Overall rank  Year  Score  GDP per capita  Social support  \
# Country or region
# Canada                        9  2019  7.278           1.365           1.505
# Austria                      10  2019  7.246           1.376           1.475
# Australia                    11  2019  7.228           1.372           1.548
# Costa Rica                   12  2019  7.167           1.034           1.441
# Israel                       13  2019  7.139           1.276           1.455
# Luxembourg                   14  2019  7.090           1.609           1.479
# United Kingdom               15  2019  7.054           1.333           1.538
# Ireland                      16  2019  7.021           1.499           1.553
#
#                    Healthy life expectancy  Freedom to make life choices  \
# Country or region
# Canada                               1.039                         0.584
# Austria                              1.016                         0.532
# ...

# %%
world
# Out:
#                           Overall rank  Year  Score  GDP per capita  \
# Country or region
# Finland                              1  2019  7.769           1.340
# Denmark                              2  2019  7.600           1.383
# Norway                               3  2019  7.554           1.488
# Iceland                              4  2019  7.494           1.380
# Netherlands                          5  2019  7.488           1.396
# ...                                ...   ...    ...             ...
# Yemen                              152  2018  3.355           0.442
# Tanzania                           153  2018  3.303           0.455
# South Sudan                        154  2018  3.254           0.337
# Central African Republic           155  2018  3.083           0.024
# Burundi                            156  2018  2.905           0.091
#
#                           Social support  Healthy life expectancy  \
# Country or region
# ...

# %%
world = world.reset_index().set_index(['Country or region', 'Year'])

# %%
world.loc['Canada', 2018]
# Out:
# Overall rank                    7.000
# Score                           7.328
# GDP per capita                  1.330
# Social support                  1.532
# Healthy life expectancy         0.896
# Freedom to make life choices    0.653
# Generosity                      0.321
# Perceptions of corruption       0.291
# Name: (Canada, 2018), dtype: float64

# %%
airbnd
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# ...

# %%
airbnd.loc[10:100]
# Out:
#      Host Id  Host Since                                 Name Neighbourhood  \
# 10      2571  27/08/2008                           THE PUTNAM      Brooklyn
# 11      2758   6/09/2008     Stay at Chez Chic budget room #1     Manhattan
# 12      2758   6/09/2008     Stay at Chez Chic budget Room #2     Manhattan
# 13      2787   7/09/2008      Renovated and spacious townhome      Brooklyn
# 14      2845   9/09/2008                       Midtown Castle     Manhattan
# ..       ...         ...                                  ...           ...
# 96      8380  22/02/2009            River view in the Village     Manhattan
# 97      8440  23/02/2009    Beautiful studio by Prospect Park      Brooklyn
# 98      8440  23/02/2009  Luxe 1BD apartment by Prospect Park      Brooklyn
# 99      8425  23/02/2009    Charming W.Village Apt. 8/25-9/15     Manhattan
# 100     8605  25/02/2009      Sunny 1BR East Harlem Apartment     Manhattan
#
# ...

# %%
world = world.reset_index().set_index(['Overall rank','Country or region']).sort_index()

# %%
world.set_index('Overall rank').sort_index().loc[1:10], world_reset.(Country or region)
# Out:
#   File "/tmp/ipython-input-3275443591.py", line 1
#     world.set_index('Overall rank').sort_index().loc[1:10], world_reset.(Country or region)
#                                                                         ^
# SyntaxError: invalid syntax

# %%
display(world_reset['Country or region'].head())
# Out:
# 0    Finland
# 1    Finland
# 2    Denmark
# 3     Norway
# 4    Denmark
# Name: Country or region, dtype: object

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                2062
# Data Scientist               1852
# Data Analyst                 1322
# Machine Learning Engineer     908
# Applied Scientist             258
#                              ...
# Marketing Data Engineer         1
# Manager Data Management         1
# Data Science Tech Lead          1
# Principal Data Architect        1
# Cloud Data Architect            1
# Name: count, Length: 124, dtype: int64

# %%
pd.DataFrame(salaries['job_title'].value_counts() )
# Out:
#                            count
# job_title
# Data Engineer               2062
# Data Scientist              1852
# Data Analyst                1322
# Machine Learning Engineer    908
# Applied Scientist            258
# ...                          ...
# Marketing Data Engineer        1
# Manager Data Management        1
# Data Science Tech Lead         1
# Principal Data Architect       1
# Cloud Data Architect           1
#
# [124 rows x 1 columns]

# %%
salaries['job_title'].value_counts().head(20)
# Out:
# job_title
# Data Engineer                     2062
# Data Scientist                    1852
# Data Analyst                      1322
# Machine Learning Engineer          908
# Applied Scientist                  258
# Research Scientist                 245
# Analytics Engineer                 241
# Data Architect                     199
# Business Intelligence Engineer     134
# Research Engineer                  133
# Data Manager                       130
# ML Engineer                        100
# Data Science Manager                92
# Machine Learning Scientist          70
# BI Developer                        50
# Business Intelligence Analyst       48
# Data Science Consultant             40
# Data Specialist                     40
# Data Analytics Manager              39
# Decision Scientist                  38
# Name: count, dtype: int64

# %%
top_20_jobs = pd.DataFrame(salaries['job_title'].value_counts() )

# %%
top_20_jobs
# Out:
#                            count
# job_title
# Data Engineer               2062
# Data Scientist              1852
# Data Analyst                1322
# Machine Learning Engineer    908
# Applied Scientist            258
# ...                          ...
# Marketing Data Engineer        1
# Manager Data Management        1
# Data Science Tech Lead         1
# Principal Data Architect       1
# Cloud Data Architect           1
#
# [124 rows x 1 columns]

# %%
top_20_jobs.plot(kind='bar')
# Out:
# <Axes: xlabel='job_title'>

# %%
top_20_jobs.plot(kind='barh')
# Out:
# <Axes: ylabel='job_title'>

# %%
top_20_jobs.sort_values(by = 'count').plot(kind='barh')
# Out:
# <Axes: ylabel='job_title'>

# %%
top_20_jobs.sort_values(by = 'count').plot(kind='barh', color = 'red')
# Out:
# <Axes: ylabel='job_title'>

# %%
salaries['experience_level'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>
