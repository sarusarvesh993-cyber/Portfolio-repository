# %%
import pandas as pd
import matplotlib.pyplot as plt
world = pd.read_csv('2018-2019 Happiness.csv') #Importing world hapiness dataset
airbnd = pd.read_csv('airbnb.csv')
salaries = pd.read_csv('salaries.csv')
websales= pd.read_csv('web_sales.csv')
eth = pd.read_csv('Ethereum Historical Data.csv', index_col= 'Date')

# %%
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8805 entries, 0 to 8804
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           8805 non-null   int64
#  1   experience_level    8805 non-null   object
#  2   employment_type     8805 non-null   object
#  3   job_title           8805 non-null   object
#  4   salary              8805 non-null   int64
#  5   salary_currency     8805 non-null   object
#  6   salary_in_usd       8805 non-null   int64
#  7   employee_residence  8805 non-null   object
#  8   remote_ratio        8805 non-null   int64
#  9   company_location    8805 non-null   object
#  10  company_size        8805 non-null   object
# dtypes: int64(4), object(7)
# memory usage: 756.8+ KB

# %%
airbnd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30478 entries, 0 to 30477
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Host Id                     30478 non-null  int64
#  1   Host Since                  30475 non-null  object
#  2   Name                        30478 non-null  object
#  3   Neighbourhood               30478 non-null  object
#  4   Property Type               30475 non-null  object
#  5   Review Scores Rating (bin)  22155 non-null  float64
#  6   Room Type                   30478 non-null  object
#  7   Zipcode                     30344 non-null  float64
#  8   Beds                        30393 non-null  float64
#  9   Number of Records           30478 non-null  int64
#  10  Number Of Reviews           30478 non-null  int64
#  11  Price                       30478 non-null  int64
#  12  Review Scores Rating        22155 non-null  float64
# ...

# %%
airbnd.isna().sum()
# Out:
# Host Id                          0
# Host Since                       3
# Name                             0
# Neighbourhood                    0
# Property Type                    3
# Review Scores Rating (bin)    8323
# Room Type                        0
# Zipcode                        134
# Beds                            85
# Number of Records                0
# Number Of Reviews                0
# Price                            0
# Review Scores Rating          8323
# dtype: int64

# %%
airbnd['Review Scores Rating'].head(20)
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4      96.0
# 5     100.0
# 6     100.0
# 7      94.0
# 8      90.0
# 9      96.0
# 10     98.0
# 11     93.0
# 12     91.0
# 13      NaN
# 14     97.0
# 15     95.0
# 16     99.0
# 17     93.0
# 18     85.0
# 19      NaN
# Name: Review Scores Rating, dtype: float64

# %%
airbnd['Review Scores Rating'].isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 30473     True
# 30474     True
# 30475     True
# 30476     True
# 30477     True
# Name: Review Scores Rating, Length: 30478, dtype: bool

# %%
airbnd[airbnd['Review Scores Rating'].isna()]
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 13         2787   7/09/2008     Renovated and spacious townhome      Brooklyn
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# ...

# %%
airbnd['Zipcode'].notna()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 30473    True
# 30474    True
# 30475    True
# 30476    True
# 30477    True
# Name: Zipcode, Length: 30478, dtype: bool

# %%
airbnd[airbnd['Zipcode'].isna()]
# Out:
#         Host Id  Host Since                                 Name  \
# 133       13654  16/04/2009   Room with a view in Central Harlem
# 234       30990  11/08/2009    Stay in the Meatpacking District!
# 333       47716  22/10/2009      $45 L train/ 1 bedroom Brooklyn
# 368       52677   9/11/2009            Columbus Avenue Apartment
# 426       58366  29/11/2009        Lincoln Center  luxury condo,
# ...         ...         ...                                  ...
# 28995  37248069   1/07/2015                Room on Prospect Park
# 29947  40585961   5/08/2015          Large Lower East Side 1 BDR
# 30127  41425363  13/08/2015   Quaint Colonial with lots of charm
# 30183  41619645  16/08/2015                        MyPlace2Beach
# 30462  42952645  30/08/2015  Waterfront Penthouse~5min > TimesSQ
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 133       Manhattan     Apartment                        85.0
# ...

# %%
airbnd['Neighbourhood'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Bronx', 'Staten Island'],
#       dtype=object)

# %%
airbnd['Room Type'].unique()
# Out:
# array(['Entire home/apt', 'Private room', 'Shared room'], dtype=object)

# %%
airbnd['Zipcode'].nunique()
# Out:
# 188

# %%
websales['SalesTerritoryCountry'].unique()
# Out:
# array(['Canada', 'France', 'United States', 'Australia', 'United Kingdom',
#        'Germany'], dtype=object)

# %%
websales['product_subcategory'].unique()
# Out:
# array(['Road Bikes', 'Mountain Bikes', 'Bottles and Cages',
#        'Touring Bikes', 'Helmets', 'Tires and Tubes', 'Bike Stands',
#        'Jerseys', 'Gloves', 'Fenders', 'Caps', 'Socks', 'Hydration Packs',
#        'Vests', 'Cleaners', 'Bike Racks', 'Shorts'], dtype=object)

# %%
websales['product'].nunique()
# Out:
# 130

# %%
airbnd[airbnd['Price'].between(100,200)]
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                 Name  \
# 0       5162530         NaN      1 Bedroom in Prime Williamsburg
# 3           500  26/06/2008   Gorgeous 1 BR with Private Balcony
# 5          1039  25/07/2008   Big Greenpoint 1BD w/ Skyline View
# 10         2571  27/08/2008                           THE PUTNAM
# 16         2965  14/09/2008      Large Bedroom in 3-bedroom Apt.
# ...         ...         ...                                  ...
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
# 30468  18223173  31/08/2015        Lovely East Village Apartment
# 30469  43018396  31/08/2015   Cute East Village Studio Sept 8-16
# ...

# %%
airbnd[airbnd['Beds'].between(3,5)]
# Out:
#         Host Id  Host Since                                 Name  \
# 3           500  26/06/2008   Gorgeous 1 BR with Private Balcony
# 4           500  26/06/2008             Trendy Times Square Loft
# 18         3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4
# 19         3226  26/09/2008       Great 3 Bed Apt Tribeca / Soho
# 28         3867  29/10/2008    3 bedroom apartment in Chinatown!
# ...         ...         ...                                  ...
# 30445  42952645  30/08/2015  3 Beds near Central Park /Lincoln C
# 30448  42897684  30/08/2015        Comfy Couch in my Living Room
# 30449  42897684  30/08/2015     Cozy, Comfortable and Convenient
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
# 30473  43022976  31/08/2015    10 Mins to Time Square/two floors
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 3         Manhattan     Apartment                         NaN
# ...

# %%
airbnd[airbnd['Beds'].between(3,5)]['Beds'].value_counts()
# Out:
# Beds
# 3.0    2071
# 4.0     783
# 5.0     284
# Name: count, dtype: int64

# %%
airbnd[airbnd['Price'].between(100,200) & airbnd['Beds'].between(3,5) ]
# Out:
#         Host Id  Host Since                                 Name  \
# 3           500  26/06/2008   Gorgeous 1 BR with Private Balcony
# 18         3227  26/09/2008  Priv Apt,Garden,BBQ,A/C,BigTV,for 4
# 36         4488  21/11/2008           Sunny & Bright Harlem Home
# 39         5871  31/12/2008          Bergen's Best Short Stay 2!
# 40         5871  31/12/2008                       Bergen's Best!
# ...         ...         ...                                  ...
# 30359  42481372  25/08/2015        West Village/Triplex/Sleeps 6
# 30386  42602208  26/08/2015            Apartment off Forest Park
# 30396  42684774  27/08/2015  Luxury 2 Bedroom /Sleep 6 / Doorman
# 30398  42679452  27/08/2015    Private Patio Midtown Apt Sleep 5
# 30467  42995294  31/08/2015   Colorful, comfortable artsy 2 bdrm
#
#       Neighbourhood Property Type  Review Scores Rating (bin)  \
# 3         Manhattan     Apartment                         NaN
# ...

# %%
airbnd[(airbnd['Property Type'] == 'Apartments') & (airbnd['Neighbourhood'] == 'Brookklyn')]
# Out:
# Empty DataFrame
# Columns: [Host Id, Host Since, Name, Neighbourhood, Property Type, Review Scores Rating (bin), Room Type, Zipcode, Beds, Number of Records, Number Of Reviews, Price, Review Scores Rating]
# Index: []

# %%
airbnd[(airbnd['Property Type'] == 'Apartments') & (airbnd['Neighbourhood'] == 'Brookklyn') & (airbnd['Price']< 100)]
# Out:
# Empty DataFrame
# Columns: [Host Id, Host Since, Name, Neighbourhood, Property Type, Review Scores Rating (bin), Room Type, Zipcode, Beds, Number of Records, Number Of Reviews, Price, Review Scores Rating]
# Index: []

# %%
salaries['job_title'].value_counts()
# Out:
# job_title
# Data Engineer                2062
# Data Scientist               1852
# Data Analyst                 1322
# Machine Learning Engineer     908
# Applied Scientist             258
#                              ...
# Marketing Data Engineer         1
# Manager Data Management         1
# Data Science Tech Lead          1
# Principal Data Architect        1
# Cloud Data Architect            1
# Name: count, Length: 124, dtype: int64

# %%
salaries[salaries['job_title'] == 'Data Engineer']
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 14         2023               MI              FT  Data Engineer  133000
# 15         2023               MI              FT  Data Engineer   58300
# 18         2023               SE              FT  Data Engineer  300000
# 19         2023               SE              FT  Data Engineer  195000
# 50         2023               SE              FT  Data Engineer  205500
# ...         ...              ...             ...            ...     ...
# 8763       2020               MI              FT  Data Engineer  110000
# 8768       2021               SE              FT  Data Engineer   65000
# 8789       2021               MI              FT  Data Engineer   38400
# 8793       2020               MI              FT  Data Engineer  130800
# 8798       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[(salaries['job_title'] == 'Data Engineer') | (salaries['job_title'] == 'Data Analyst')]
# Out:
#       work_year experience_level employment_type      job_title  salary  \
# 14         2023               MI              FT  Data Engineer  133000
# 15         2023               MI              FT  Data Engineer   58300
# 16         2023               SE              FT   Data Analyst  145640
# 17         2023               SE              FT   Data Analyst   84400
# 18         2023               SE              FT  Data Engineer  300000
# ...         ...              ...             ...            ...     ...
# 8786       2021               MI              FT   Data Analyst   75000
# 8787       2021               MI              FT   Data Analyst   62000
# 8789       2021               MI              FT  Data Engineer   38400
# 8793       2020               MI              FT  Data Engineer  130800
# 8798       2021               MI              FT  Data Engineer   24000
#
#      salary_currency  salary_in_usd employee_residence  remote_ratio  \
# ...

# %%
salaries[((salaries['job_title'] == 'Data Engineer')
  | (salaries['job_title'] == 'Data Analyst'))
 & (salaries['salary_in_usd'] > 2000000)]['job_title'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
salaries[((salaries['job_title'] == 'Data Engineer')
  | (salaries['job_title'] == 'Data Analyst'))
 & (salaries['salary_in_usd'] > 2000000)]['job_title'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
airbnd[airbnd['Property Type'].isin(['Bed & Breakfast', 'Loft', 'Cabin', 'Villa', 'Lighthouse'])]
# Out:
#         Host Id  Host Since                                 Name  \
# 50         5926   2/01/2009   Nice  Apt Near Columbia University
# 59         7351   2/02/2009   2 Floor Loft room in Artist Studio
# 60         7351   2/02/2009  Spacious Loft Room in Artist Studio
# 61         7351   2/02/2009    Spacious room in Huge artist Loft
# 92         8057  17/02/2009  HUGE MODERN LUXURY-2bed/2bath+patio
# ...         ...         ...                                  ...
# 30373  42518458  25/08/2015   Williamsburg luxury loft!King Room
# 30377  42520959  25/08/2015  1Bedroom in HUGE Times Square LOFT!
# 30378  42518458  25/08/2015   Williamsburg Luxury Loft!??Bed Top
# 30440  42918586  30/08/2015         1800 sq ft studio for shoots
# 30461  42917787  30/08/2015  East Village,  First floor.  new bg
#
#       Neighbourhood    Property Type  Review Scores Rating (bin)  \
# 50        Manhattan  Bed & Breakfast                        85.0
# ...

# %%
airbnd[~airbnd['Property Type'].isin(['Bed & Breakfast', 'Loft', 'Cabin', 'Villa', 'Lighthouse'])]
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# ...

# %%
airbnd['City'] = 'New York'

# %%
airbnd
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# ...

# %%
airbnd.drop(labels = 'City' , axis = 1, inplace = True)

# %%
airbnd['Number of Records'].value_counts()
# Out:
# Number of Records
# 1    30478
# Name: count, dtype: int64

# %%
airbnd.drop(labels = 'Number of Records' , axis = 1, inplace = True)

# %%
airbnd
# Out:
# /usr/local/lib/python3.11/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#         Host Id  Host Since                                Name Neighbourhood  \
# 0       5162530         NaN     1 Bedroom in Prime Williamsburg      Brooklyn
# 1      33134899         NaN     Sunny, Private room in Bushwick      Brooklyn
# 2      39608626         NaN                Sunny Room in Harlem     Manhattan
# 3           500  26/06/2008  Gorgeous 1 BR with Private Balcony     Manhattan
# 4           500  26/06/2008            Trendy Times Square Loft     Manhattan
# ...         ...         ...                                 ...           ...
# 30473  43022976  31/08/2015   10 Mins to Time Square/two floors        Queens
# ...

# %%
websales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
websales['Sales with Tax Freight'] = websales['SalesAmount'] + websales['TaxAmt'] + websales['Freight']

# %%
websales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
# [1502 rows x 7 columns]

# %%
eth['Volatility'] = eth['High'] - eth['Low']

# %%
eth
# Out:
#            Coin    Price     Open     High      Low     Vol. Change %  \
# Date
# 10/02/2024  ETH  2508.31  2486.24  2514.83  2483.50  504.80K    0.89%
# 9/02/2024   ETH  2486.24  2419.56  2522.96  2419.16  540.92K    2.76%
# 8/02/2024   ETH  2419.56  2424.66  2461.00  2412.01  350.33K   -0.21%
# 7/02/2024   ETH  2424.64  2372.65  2443.71  2354.46  355.40K    2.19%
# 6/02/2024   ETH  2372.65  2301.83  2390.53  2299.24  381.23K    3.08%
# ...         ...      ...      ...      ...      ...      ...      ...
# 5/01/2020   ETH   135.59   134.32   138.33   134.32   12.19M    0.94%
# 4/01/2020   ETH   134.33   134.30   135.57   132.76   11.16M    0.04%
# 3/01/2020   ETH   134.27   127.19   134.86   126.05   15.67M    5.56%
# 2/01/2020   ETH   127.19   130.75   130.77   126.74   11.45M   -2.72%
# 1/01/2020   ETH   130.75   129.21   132.97   128.81   10.35M    1.19%
#
#             Volatility
# Date
# 10/02/2024       31.33
# 9/02/2024       103.80
# 8/02/2024        48.99
# ...

# %%
websales['Sales Type'] = websales['product_subcategory'] +' '+ websales['SalesTerritoryCountry']

# %%
websales
# Out:
#        ProductKey                  product product_subcategory  OrderDateKey  \
# 0             310         Road-150 Red, 62          Road Bikes      20101229
# 1             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 2             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# 3             336       Road-650 Black, 62          Road Bikes      20101229
# 4             346  Mountain-100 Silver, 44      Mountain Bikes      20101229
# ...           ...                      ...                 ...           ...
# 60393         485    Fender Set - Mountain             Fenders      20140128
# 60394         225             AWC Logo Cap                Caps      20140128
# 60395         485    Fender Set - Mountain             Fenders      20140128
# 60396         486   All-Purpose Bike Stand         Bike Stands      20140128
# 60397         225             AWC Logo Cap                Caps      20140128
#
# ...
